# %% [markdown]
# # Novelty Detection

# %% [markdown]
# ## Part 1
# Deep purple & Johnny Cash samples

# %%
# Part 1

from pandas import DataFrame
import pandas as pd

dp_jc_df = pd.read_csv('./dp_jc_samples.csv')
jc_dp_df = pd.read_csv('./jc_dp_samples.csv')

# Shuffle rows as for each csv file, novelty rows are appended to the end of dataset
# dp_jc_ds = dp_jc_df.sample(frac=1)
dp_jc_ds = dp_jc_df
# jc_dp_ds = jc_dp_df.sample(frac=1)
jc_dp_ds = jc_dp_df

# Drop columns 'Class' and 'Path'
dp_jc_ds_cleaned = dp_jc_ds.drop(['Path', 'Class'], axis=1)
jc_dp_ds_cleaned = jc_dp_ds.drop(['Path', 'Class'], axis=1)

dp_jc_train_samples = dp_jc_ds_cleaned.values.tolist()
jc_dp_train_samples = jc_dp_ds_cleaned.values.tolist()

# %%
from collections import Counter
from sklearn import svm
import numpy as np

estimator = svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.1)

# Deep Purple with Johnny Cash novelty samples
estimator.fit(dp_jc_train_samples)
dp_jc_pred = estimator.predict(dp_jc_train_samples)

print("Deep Purple - Johnny Cash Outlier Analysis:")
dp_jc_outlier_count = Counter(dp_jc_pred)
print("Outlier Count: ", dp_jc_outlier_count[-1])
print("Inlier Count: ", dp_jc_outlier_count[1])

# Add outliers data as last column to data sample
dp_jc_ds["Outliers"] = dp_jc_pred

# Get only Johnny Cash rows (should be 10 rows)
jc_samples = dp_jc_ds.loc[dp_jc_ds["Class"] == 'Johnny_cash']

for sample in jc_samples.values.tolist():
    print("{} ---> {}".format(sample[0], "Outlier (-1)" if sample[-1] == -1 else "Inlier (1)"))

jc_outliers_count = len(jc_samples.loc[jc_samples["Outliers"] == -1])

print("\nOut of 10 Johnny Cash samples, {} are outliers".format(jc_outliers_count))
print("Detection rate: {}%".format((jc_outliers_count/10)*100))
# Out:
# Deep Purple - Johnny Cash Outlier Analysis:
# Outlier Count:  66
# Inlier Count:  44
# Johnny_cash/01 - Cold Lonesome Morning.mp3.wav ---> Outlier (-1)
# Johnny_cash/01 - Flesh and Blood.mp3.wav ---> Outlier (-1)
# Johnny_cash/01 - From Sea To Shining Sea.mp3.wav ---> Outlier (-1)
# Johnny_cash/01 - Gone Girl.mp3.wav ---> Outlier (-1)
# Johnny_cash/01 - Hiawathas Vision.mp3.wav ---> Outlier (-1)
# Johnny_cash/01 - Let There Be Country.mp3.wav ---> Outlier (-1)
# Johnny_cash/01 - Rollin Free.mp3.wav ---> Outlier (-1)
# Johnny_cash/01 - Southwind.mp3.wav ---> Outlier (-1)
# Johnny_cash/02 - Ballad of Little Fauss and Big Halsy.mp3.wav ---> Inlier (1)
# Johnny_cash/02 - I Walk the Line (Full Version).mp3.wav ---> Inlier (1)
#
# Out of 10 Johnny Cash samples, 8 are outliers
# Detection rate: 80.0%
#                                                   Path        Class  \
# 100     Johnny_cash/01 - Cold Lonesome Morning.mp3.wav  Johnny_cash
# 101           Johnny_cash/01 - Flesh and Blood.mp3.wav  Johnny_cash
# 102   Johnny_cash/01 - From Sea To Shining Sea.mp3.wav  Johnny_cash
# 103                 Johnny_cash/01 - Gone Girl.mp3.wav  Johnny_cash
# 104          Johnny_cash/01 - Hiawathas Vision.mp3.wav  Johnny_cash
# 105      Johnny_cash/01 - Let There Be Country.mp3.wav  Johnny_cash
# 106               Johnny_cash/01 - Rollin Free.mp3.wav  Johnny_cash
# 107                 Johnny_cash/01 - Southwind.mp3.wav  Johnny_cash
# 108  Johnny_cash/02 - Ballad of Little Fauss and Bi...  Johnny_cash
# 109  Johnny_cash/02 - I Walk the Line (Full Version...  Johnny_cash
#
#      Spectral Centroid Overall Average 1  \
# 100                                 30.2
# 101                                 20.8
# 102                                 20.6
# 103                                 27.1
# 104                                 18.0
# 105                                 19.1
# 106                                 19.7
# 107                                 22.3
# 108                                 19.3
# 109                                 14.4
#
#      Spectral Centroid Overall Standard Deviation 1  \
# 100                                           15.40
# 101                                           13.30
# 102                                           13.20
# 103                                           13.10
# 104                                           15.20
# 105                                            8.25
# 106                                           11.60
# 107                                           16.40
# 108                                           12.50
# 109                                           10.90
#
#      Spectral Rolloff Point Overall Average 1  \
# 100                                    0.2130
# 101                                    0.1460
# 102                                    0.1250
# 103                                    0.1710
# 104                                    0.1050
# 105                                    0.1190
# 106                                    0.1350
# 107                                    0.1610
# 108                                    0.1370
# 109                                    0.0866
#
#      Spectral Rolloff Point Overall Standard Deviation 1  \
# 100                                             0.1390
# 101                                             0.1260
# 102                                             0.1200
# 103                                             0.1090
# 104                                             0.1250
# 105                                             0.0761
# 106                                             0.1230
# 107                                             0.1430
# 108                                             0.1220
# 109                                             0.0908
#
#      Spectral Flux Overall Average 1  \
# 100                         0.001470
# 101                         0.001670
# 102                         0.000398
# 103                         0.002720
# 104                         0.002230
# 105                         0.000497
# 106                         0.001580
# 107                         0.000597
# 108                         0.001670
# 109                         0.001260
#
#      Spectral Flux Overall Standard Deviation 1  \
# 100                                    0.001960
# 101                                    0.001740
# 102                                    0.000460
# 103                                    0.002630
# 104                                    0.003690
# 105                                    0.000680
# 106                                    0.001890
# 107                                    0.000809
# 108                                    0.003150
# 109                                    0.002010
#
#      Compactness Overall Average 1  Compactness Overall Standard Deviation 1  \
# 100                           1658                                     170.0
# 101                           1687                                     184.0
# 102                           1637                                     165.0
# 103                           1684                                     161.0
# 104                           1598                                     185.0
# 105                           1654                                     175.0
# 106                           1689                                     228.0
# 107                           1628                                     189.0
# 108                           1599                                     192.0
# 109                           1657                                     227.0
#
#      ...  Method of Moments Overall Average 2  \
# 100  ...                               0.2910
# 101  ...                               0.1430
# 102  ...                               0.0935
# 103  ...                               0.2220
# 104  ...                               0.0946
# 105  ...                               0.1220
# 106  ...                               0.1080
# 107  ...                               0.1950
# 108  ...                               0.1350
# 109  ...                               0.1000
#
#      Method of Moments Overall Average 3  Method of Moments Overall Average 4  \
# 100                                 74.0                                18770
# 101                                 36.5                                 9274
# 102                                 23.8                                 6053
# 103                                 56.4                                14290
# 104                                 24.1                                 6125
# 105                                 31.1                                 7916
# 106                                 27.6                                 7026
# 107                                 49.8                                12660
# 108                                 34.3                                 8737
# 109                                 25.5                                 6477
#
#      Method of Moments Overall Average 5  \
# 100                              4775000
# 101                              2362000
# 102                              1542000
# 103                              3631000
# 104                              1560000
# 105                              2017000
# 106                              1790000
# 107                              3223000
# 108                              2226000
# 109                              1649000
#
#      Method of Moments Overall Standard Deviation 1  \
# 100                                          0.1360
# 101                                          0.1790
# 102                                          0.0926
# 103                                          0.2240
# 104                                          0.1860
# 105                                          0.1100
# 106                                          0.1720
# 107                                          0.0965
# 108                                          0.2160
# 109                                          0.1890
#
#      Method of Moments Overall Standard Deviation 2  \
# 100                                           0.316
# 101                                           0.173
# 102                                           0.150
# 103                                           0.393
# 104                                           0.156
# 105                                           0.114
# 106                                           0.134
# 107                                           0.169
# 108                                           0.103
# 109                                           0.147
#
#      Method of Moments Overall Standard Deviation 3  \
# 100                                            80.0
# 101                                            44.0
# 102                                            38.1
# 103                                            96.7
# 104                                            39.5
# 105                                            29.1
# 106                                            34.0
# 107                                            43.0
# 108                                            26.1
# 109                                            37.5
#
#      Method of Moments Overall Standard Deviation 4  \
# 100                                           20140
# 101                                           11140
# 102                                            9644
# 103                                           22990
# 104                                           10000
# 105                                            7392
# 106                                            8623
# 107                                           10890
# 108                                            6640
# 109                                            9503
#
#      Method of Moments Overall Standard Deviation 5  Outliers
# 100                                         5102000        -1
# 101                                         2832000        -1
# 102                                         2449000        -1
# 103                                         5685000        -1
# 104                                         2541000        -1
# 105                                         1881000        -1
# 106                                         2193000        -1
# 107                                         2770000        -1
# 108                                         1690000         1
# 109                                         2417000         1
#
# [10 rows x 81 columns]

# %%
# Johnny Cash with Deep Purple novelty samples
estimator.fit(jc_dp_train_samples)
jc_dp_pred = estimator.predict(jc_dp_train_samples)

# Add outliers data as last column to data sample
jc_dp_ds["Outliers"] = jc_dp_pred

print("\nJohnny Cash - Deep Purple Outlier Analysis:")
jc_dp_outlier_count = Counter(jc_dp_pred)
print("Outlier Count: ", jc_dp_outlier_count[-1])
print("Inlier Count: ", jc_dp_outlier_count[1])

# Get only Deep Purple rows (should be 10 rows)
dp_samples = jc_dp_ds.loc[jc_dp_ds["Class"] == 'deep_purple']

for sample in dp_samples.values.tolist():
    print("{} ---> {}".format(sample[0], "Outlier (-1)" if sample[-1] == -1 else "Inlier (1)"))

dp_outliers_count = len(dp_samples.loc[dp_samples["Outliers"] == -1])

print("\nOut of 10 Deep Purple samples, {} are outliers".format(dp_outliers_count))
print("Detection rate: {}%".format((dp_outliers_count/10)*100))
# Out:
# Johnny Cash - Deep Purple Outlier Analysis:
# Outlier Count:  66
# Inlier Count:  44
# deep_purple/01 - Highway Star.mp3.wav ---> Outlier (-1)
# deep_purple/02 - Maybe I m A Leo.mp3.wav ---> Outlier (-1)
# deep_purple/03 - Pictures Of Hom.mp3.wav ---> Outlier (-1)
# deep_purple/04 - Never Before.mp3.wav ---> Outlier (-1)
# deep_purple/05 - Smoke On The Wa.mp3.wav ---> Outlier (-1)
# deep_purple/06 - Lazy.mp3.wav ---> Outlier (-1)
# deep_purple/07 - Space Truckin.mp3.wav ---> Outlier (-1)
# deep_purple/DEEP PURPLE - COME TASTE THE BAND - 01 - COMIN HOME.mp3.wav ---> Outlier (-1)
# deep_purple/DEEP PURPLE - COME TASTE THE BAND - 02 - LADY LUCK.mp3.wav ---> Inlier (1)
# deep_purple/DEEP PURPLE - COME TASTE THE BAND - 03 - GETTIN TIGHTER.mp3.wav ---> Inlier (1)
#
# Out of 10 Deep Purple samples, 8 are outliers
# Detection rate: 80.0%
#                                                   Path        Class  \
# 100              deep_purple/01 - Highway Star.mp3.wav  deep_purple
# 101           deep_purple/02 - Maybe I m A Leo.mp3.wav  deep_purple
# 102           deep_purple/03 - Pictures Of Hom.mp3.wav  deep_purple
# 103              deep_purple/04 - Never Before.mp3.wav  deep_purple
# 104           deep_purple/05 - Smoke On The Wa.mp3.wav  deep_purple
# 105                      deep_purple/06 - Lazy.mp3.wav  deep_purple
# 106             deep_purple/07 - Space Truckin.mp3.wav  deep_purple
# 107  deep_purple/DEEP PURPLE - COME TASTE THE BAND ...  deep_purple
# 108  deep_purple/DEEP PURPLE - COME TASTE THE BAND ...  deep_purple
# 109  deep_purple/DEEP PURPLE - COME TASTE THE BAND ...  deep_purple
#
#      Spectral Centroid Overall Average 1  \
# 100                                 32.8
# 101                                 26.1
# 102                                 29.3
# 103                                 29.6
# 104                                 18.8
# 105                                 29.6
# 106                                 27.0
# 107                                 26.0
# 108                                 26.1
# 109                                 30.4
#
#      Spectral Centroid Overall Standard Deviation 1  \
# 100                                           16.40
# 101                                           23.30
# 102                                           15.90
# 103                                           18.80
# 104                                           14.30
# 105                                           27.50
# 106                                           18.80
# 107                                            9.00
# 108                                            9.69
# 109                                           15.60
#
#      Spectral Rolloff Point Overall Average 1  \
# 100                                     0.240
# 101                                     0.192
# 102                                     0.203
# 103                                     0.219
# 104                                     0.122
# 105                                     0.186
# 106                                     0.200
# 107                                     0.176
# 108                                     0.185
# 109                                     0.231
#
#      Spectral Rolloff Point Overall Standard Deviation 1  \
# 100                                             0.1790
# 101                                             0.2060
# 102                                             0.1830
# 103                                             0.2070
# 104                                             0.1450
# 105                                             0.1790
# 106                                             0.1840
# 107                                             0.0699
# 108                                             0.0868
# 109                                             0.1540
#
#      Spectral Flux Overall Average 1  \
# 100                         0.001260
# 101                         0.000425
# 102                         0.000658
# 103                         0.000697
# 104                         0.000661
# 105                         0.000131
# 106                         0.000692
# 107                         0.002740
# 108                         0.002450
# 109                         0.002450
#
#      Spectral Flux Overall Standard Deviation 1  \
# 100                                    0.001280
# 101                                    0.000573
# 102                                    0.000714
# 103                                    0.000911
# 104                                    0.000980
# 105                                    0.000210
# 106                                    0.000879
# 107                                    0.002140
# 108                                    0.002230
# 109                                    0.002510
#
#      Compactness Overall Average 1  Compactness Overall Standard Deviation 1  \
# 100                           1580                                     156.0
# 101                           1582                                     172.0
# 102                           1580                                     164.0
# 103                           1598                                     166.0
# 104                           1541                                     171.0
# 105                           1633                                     203.0
# 106                           1560                                     161.0
# 107                           1570                                     138.0
# 108                           1574                                     144.0
# 109                           1589                                     149.0
#
#      ...  Method of Moments Overall Average 2  \
# 100  ...                                0.531
# 101  ...                                0.498
# 102  ...                                0.474
# 103  ...                                0.502
# 104  ...                                0.414
# 105  ...                                0.218
# 106  ...                                0.439
# 107  ...                                0.153
# 108  ...                                0.245
# 109  ...                                0.318
#
#      Method of Moments Overall Average 3  Method of Moments Overall Average 4  \
# 100                                135.0                                34140
# 101                                126.0                                31960
# 102                                121.0                                30530
# 103                                128.0                                32310
# 104                                105.0                                26660
# 105                                 55.3                                13990
# 106                                112.0                                28260
# 107                                 39.1                                 9940
# 108                                 62.3                                15830
# 109                                 80.8                                20530
#
#      Method of Moments Overall Average 5  \
# 100                              8675000
# 101                              8115000
# 102                              7762000
# 103                              8209000
# 104                              6779000
# 105                              3552000
# 106                              7185000
# 107                              2532000
# 108                              4031000
# 109                              5225000
#
#      Method of Moments Overall Standard Deviation 1  \
# 100                                           0.129
# 101                                           0.109
# 102                                           0.103
# 103                                           0.117
# 104                                           0.123
# 105                                           0.132
# 106                                           0.103
# 107                                           0.153
# 108                                           0.175
# 109                                           0.200
#
#      Method of Moments Overall Standard Deviation 2  \
# 100                                           0.449
# 101                                           0.535
# 102                                           0.381
# 103                                           0.466
# 104                                           0.356
# 105                                           0.440
# 106                                           0.375
# 107                                           0.120
# 108                                           0.207
# 109                                           0.249
#
#      Method of Moments Overall Standard Deviation 3  \
# 100                                           114.0
# 101                                           135.0
# 102                                            96.3
# 103                                           118.0
# 104                                            90.2
# 105                                           111.0
# 106                                            94.9
# 107                                            30.6
# 108                                            52.5
# 109                                            63.2
#
#      Method of Moments Overall Standard Deviation 4  \
# 100                                         28530.0
# 101                                         33730.0
# 102                                         24160.0
# 103                                         29530.0
# 104                                         22710.0
# 105                                         27550.0
# 106                                         23880.0
# 107                                          7757.0
# 108                                         13290.0
# 109                                         15970.0
#
#      Method of Moments Overall Standard Deviation 5  Outliers
# 100                                       7220000.0        -1
# 101                                       8518000.0        -1
# 102                                       6114000.0        -1
# 103                                       7469000.0        -1
# 104                                       5755000.0        -1
# 105                                       6941000.0        -1
# 106                                       6049000.0        -1
# 107                                       1974000.0        -1
# 108                                       3376000.0         1
# 109                                       4053000.0         1
#
# [10 rows x 81 columns]

# %%
gammas = [0.05, 0.2, 0.3, 0.45, 0.63, 0.78]

predictions: dict = {"Gamma": [], "Musician 1 among musician 2": [], "Musician 2 among musician 1": []}
for gamma in gammas:
    # Add gammas to gamma list
    predictions["Gamma"].append(gamma)

    # Instantiate estimator
    estimator = svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=gamma)
    
    # Predict JC outliers in DP data set
    estimator.fit(dp_jc_train_samples)
    dp_jc_pred = estimator.predict(dp_jc_train_samples)

    # Add outliers as column in data sample
    dp_jc_ds["Outliers"] = dp_jc_pred

    # Get only Johnny Cash rows (should be 10 rows)
    jc_samples = dp_jc_ds.loc[dp_jc_ds["Class"] == 'Johnny_cash']

    # Get outlier count
    jc_outliers_count = len(dp_samples.loc[jc_samples["Outliers"] == -1])

    predictions["Musician 2 among musician 1"].append(jc_outliers_count)

    # Predict DP outliers in JC data set
    estimator.fit(jc_dp_train_samples)
    jc_dp_pred = estimator.predict(jc_dp_train_samples)

    # Add outliers as column in data sample
    jc_dp_ds["Outliers"] = jc_dp_pred

    # Get only Deep Purple rows (should be 10 rows)
    dp_samples = jc_dp_ds.loc[jc_dp_ds["Class"] == 'deep_purple']

    dp_outliers_count = len(dp_samples.loc[dp_samples["Outliers"] == -1])

    predictions["Musician 1 among musician 2"].append(dp_outliers_count)

output_df = DataFrame(data=predictions)
output_df.style.set_caption("Predictions with Variable Gammas")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6d6d4">
#   <caption>Predictions with Variable Gammas</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d6d4_level0_col0" class="col_heading level0 col0" >Gamma</th>
#       <th id="T_6d6d4_level0_col1" class="col_heading level0 col1" >Musician 1 among musician 2</th>
#       <th id="T_6d6d4_level0_col2" class="col_heading level0 col2" >Musician 2 among musician 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d6d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d6d4_row0_col0" class="data row0 col0" >0.050000</td>
#       <td id="T_6d6d4_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_6d6d4_row0_col2" class="data row0 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6d6d4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6d6d4_row1_col0" class="data row1 col0" >0.200000</td>
#       <td id="T_6d6d4_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_6d6d4_row1_col2" class="data row1 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6d6d4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6d6d4_row2_col0" class="data row2 col0" >0.300000</td>
#       <td id="T_6d6d4_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_6d6d4_row2_col2" class="data row2 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6d6d4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6d6d4_row3_col0" class="data row3 col0" >0.450000</td>
#       <td id="T_6d6d4_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_6d6d4_row3_col2" class="data row3 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6d6d4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6d6d4_row4_col0" class="data row4 col0" >0.630000</td>
#       <td id="T_6d6d4_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_6d6d4_row4_col2" class="data row4 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6d6d4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6d6d4_row5_col0" class="data row5 col0" >0.780000</td>
#       <td id="T_6d6d4_row5_col1" class="data row5 col1" >8</td>
#       <td id="T_6d6d4_row5_col2" class="data row5 col2" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Repeat process from above (using same data) using LOF instead

from sklearn.neighbors import LocalOutlierFactor
from collections import Counter

lof = LocalOutlierFactor(novelty=True, n_neighbors=20)

# Deep Purple with Johnny Cash novelty samples
lof.fit(dp_jc_train_samples)
dp_jc_pred = lof.predict(dp_jc_train_samples)

print("Deep Purple - Johnny Cash Outlier Analysis:")
dp_jc_outlier_count = Counter(dp_jc_pred)
print("Outlier Count: ", dp_jc_outlier_count[-1])
print("Inlier Count: ", dp_jc_outlier_count[1])

# Add outliers data as last column to data sample
dp_jc_ds["Outliers"] = dp_jc_pred

# Get only Johnny Cash rows (should be 10 rows)
jc_samples = dp_jc_ds.loc[dp_jc_ds["Class"] == 'Johnny_cash']

for sample in jc_samples.values.tolist():
    print("{} ---> {}".format(sample[0], "Outlier (-1)" if sample[-1] == -1 else "Inlier (1)"))

jc_outliers_count = len(jc_samples.loc[jc_samples["Outliers"] == -1])

print("\nOut of 10 Johnny Cash samples, {} are outliers".format(jc_outliers_count))
print("Detection rate: {}%".format((jc_outliers_count/10)*100))
# Out:
# Deep Purple - Johnny Cash Outlier Analysis:
# Outlier Count:  12
# Inlier Count:  98
# Johnny_cash/01 - Cold Lonesome Morning.mp3.wav ---> Inlier (1)
# Johnny_cash/01 - Flesh and Blood.mp3.wav ---> Inlier (1)
# Johnny_cash/01 - From Sea To Shining Sea.mp3.wav ---> Inlier (1)
# Johnny_cash/01 - Gone Girl.mp3.wav ---> Inlier (1)
# Johnny_cash/01 - Hiawathas Vision.mp3.wav ---> Inlier (1)
# Johnny_cash/01 - Let There Be Country.mp3.wav ---> Inlier (1)
# Johnny_cash/01 - Rollin Free.mp3.wav ---> Inlier (1)
# Johnny_cash/01 - Southwind.mp3.wav ---> Inlier (1)
# Johnny_cash/02 - Ballad of Little Fauss and Big Halsy.mp3.wav ---> Inlier (1)
# Johnny_cash/02 - I Walk the Line (Full Version).mp3.wav ---> Inlier (1)
#
# Out of 10 Johnny Cash samples, 0 are outliers
# Detection rate: 0.0%

# %%
# Johnny Cash with Deep Purple novelty samples
lof.fit(jc_dp_train_samples)
jc_dp_pred = lof.predict(jc_dp_train_samples)

# Add outliers data as last column to data sample
jc_dp_ds["Outliers"] = jc_dp_pred

print("\nJohnny Cash - Deep Purple Outlier Analysis:")
jc_dp_outlier_count = Counter(jc_dp_pred)
print("Outlier Count: ", jc_dp_outlier_count[-1])
print("Inlier Count: ", jc_dp_outlier_count[1])

# Get only Deep Purple rows (should be 10 rows)
dp_samples = jc_dp_ds.loc[jc_dp_ds["Class"] == 'deep_purple']

for sample in dp_samples.values.tolist():
    print("{} ---> {}".format(sample[0], "Outlier (-1)" if sample[-1] == -1 else "Inlier (1)"))

dp_outliers_count = len(dp_samples.loc[dp_samples["Outliers"] == -1])

print("\nOut of 10 Deep Purple samples, {} are outliers".format(dp_outliers_count))
print("Detection rate: {}%".format((dp_outliers_count/10)*100))
# Out:
# Johnny Cash - Deep Purple Outlier Analysis:
# Outlier Count:  9
# Inlier Count:  101
# deep_purple/01 - Highway Star.mp3.wav ---> Outlier (-1)
# deep_purple/02 - Maybe I m A Leo.mp3.wav ---> Outlier (-1)
# deep_purple/03 - Pictures Of Hom.mp3.wav ---> Outlier (-1)
# deep_purple/04 - Never Before.mp3.wav ---> Outlier (-1)
# deep_purple/05 - Smoke On The Wa.mp3.wav ---> Inlier (1)
# deep_purple/06 - Lazy.mp3.wav ---> Inlier (1)
# deep_purple/07 - Space Truckin.mp3.wav ---> Inlier (1)
# deep_purple/DEEP PURPLE - COME TASTE THE BAND - 01 - COMIN HOME.mp3.wav ---> Inlier (1)
# deep_purple/DEEP PURPLE - COME TASTE THE BAND - 02 - LADY LUCK.mp3.wav ---> Inlier (1)
# deep_purple/DEEP PURPLE - COME TASTE THE BAND - 03 - GETTIN TIGHTER.mp3.wav ---> Inlier (1)
#
# Out of 10 Deep Purple samples, 4 are outliers
# Detection rate: 40.0%

# %%
num_of_neighbors = [25, 38, 46, 51, 64, 79]

predictions: dict = {"Number of Neighbors": [], "Musician 1 among musician 2": [], "Musician 2 among musician 1": []}

for num in num_of_neighbors:
    # Add gammas to gamma list
    predictions["Number of Neighbors"].append(num)

    # Instantiate estimator
    lof = LocalOutlierFactor(novelty=True, n_neighbors=num)
    
    # Predict JC outliers in DP data set
    lof.fit(dp_jc_train_samples)
    dp_jc_pred = lof.predict(dp_jc_train_samples)

    # Add outliers as column in data sample
    dp_jc_ds["Outliers"] = dp_jc_pred

    # Get only Johnny Cash rows (should be 10 rows)
    jc_samples = dp_jc_ds.loc[dp_jc_ds["Class"] == 'Johnny_cash']

    # Get outlier count
    jc_outliers_count = len(dp_samples.loc[jc_samples["Outliers"] == -1])

    predictions["Musician 2 among musician 1"].append(jc_outliers_count)

    # Predict DP outliers in JC data set
    estimator.fit(jc_dp_train_samples)
    jc_dp_pred = estimator.predict(jc_dp_train_samples)

    # Add outliers as column in data sample
    jc_dp_ds["Outliers"] = jc_dp_pred

    # Get only Deep Purple rows (should be 10 rows)
    dp_samples = jc_dp_ds.loc[jc_dp_ds["Class"] == 'deep_purple']

    dp_outliers_count = len(dp_samples.loc[dp_samples["Outliers"] == -1])

    predictions["Musician 1 among musician 2"].append(dp_outliers_count)

output_df = DataFrame(data=predictions)
output_df.style.set_caption("Predictions with Variable Gammas")
# Out:
# <style type="text/css">
# </style>
# <table id="T_809d7">
#   <caption>Predictions with Variable Gammas</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_809d7_level0_col0" class="col_heading level0 col0" >Number of Neighbors</th>
#       <th id="T_809d7_level0_col1" class="col_heading level0 col1" >Musician 1 among musician 2</th>
#       <th id="T_809d7_level0_col2" class="col_heading level0 col2" >Musician 2 among musician 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_809d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_809d7_row0_col0" class="data row0 col0" >25</td>
#       <td id="T_809d7_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_809d7_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_809d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_809d7_row1_col0" class="data row1 col0" >38</td>
#       <td id="T_809d7_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_809d7_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_809d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_809d7_row2_col0" class="data row2 col0" >46</td>
#       <td id="T_809d7_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_809d7_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_809d7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_809d7_row3_col0" class="data row3 col0" >51</td>
#       <td id="T_809d7_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_809d7_row3_col2" class="data row3 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_809d7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_809d7_row4_col0" class="data row4 col0" >64</td>
#       <td id="T_809d7_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_809d7_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_809d7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_809d7_row5_col0" class="data row5 col0" >79</td>
#       <td id="T_809d7_row5_col1" class="data row5 col1" >8</td>
#       <td id="T_809d7_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Part 2
# OneClassSVM provided better performance (LOF incorrectly implies that all novelty samples are inliers)

# %%
import pandas as pd

from collections import Counter
from sklearn import svm

dp_df = pd.read_csv('./deep_purple_data.csv')

# Drop columns 'Class' and 'Path'
dp_df_cleaned = dp_df.drop(['Path', 'Class'], axis=1)

dp_df_train_samples = dp_df_cleaned.values.tolist()

estimator = svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.1)
estimator.fit(dp_df_train_samples)
dp_pred = estimator.predict(dp_df_train_samples)

print("Deep Purple Outlier Analysis:")
dp_outlier_count = Counter(dp_pred)
print("Outlier Count: ", dp_outlier_count[-1])
print("Inlier Count: ", dp_outlier_count[1])

# Add outliers data as last column to data sample
dp_df["Outliers"] = dp_pred

for sample in dp_df.values.tolist():
    if (sample[-1] == -1):
        print(sample[0])

dp_outliers_count = len(dp_df.loc[dp_df["Outliers"] == -1])

print("\nOut of {} Deep Purple samples, {} are outliers".format(dp_pred.shape[0], dp_outliers_count))
# Out:
# Deep Purple Outlier Analysis:
# Outlier Count:  107
# Inlier Count:  50
# deep_purple/DEEP PURPLE - COME TASTE THE BAND - 09 - YOU KEEP ON MOVING.mp3.wav
# deep_purple/Deep Purple - Abandon - 01 - Any Fule Kno That.mp3.wav
# deep_purple/Deep Purple - Abandon - 02 - Almost Human.mp3.wav
# deep_purple/Deep Purple - Abandon - 03 - Dont Make Me Happy.mp3.wav
# deep_purple/Deep Purple - Abandon - 04 - Seventh Heaven.mp3.wav
# deep_purple/Deep Purple - Abandon - 05 - Watching The Sky.mp3.wav
# deep_purple/Deep Purple - Abandon - 06 - Fingers To The Bone.mp3.wav
# deep_purple/Deep Purple - Abandon - 07 - Jack Ruby.mp3.wav
# deep_purple/Deep Purple - Abandon - 08 - She Was.mp3.wav
# deep_purple/Deep Purple - Abandon - 09 - Whatsername.mp3.wav
# deep_purple/Deep Purple - Abandon - 10 - 69.mp3.wav
# deep_purple/Deep Purple - Abandon - 11 - Evil Louie.mp3.wav
# deep_purple/Deep Purple - Abandon - 12 - Bludsucker.mp3.wav
# deep_purple/Deep Purple - Bananas - 05 - Silver Tongue.mp3.wav
# deep_purple/Deep Purple - Bananas - 06 - Walk On.mp3.wav
# deep_purple/Deep Purple - Bananas - 07 - picture of innocence.mp3.wav
# deep_purple/Deep Purple - Burn - 01 - Burn.mp3.wav
# deep_purple/Deep Purple - Burn - 02 - Might Just Take Your Life.mp3.wav
# deep_purple/Deep Purple - Burn - 03 - Lay Down Stay Down.mp3.wav
# deep_purple/Deep Purple - Burn - 04 - Sail Away.mp3.wav
# deep_purple/Deep Purple - Burn - 05 - You Fool No One.mp3.wav
# deep_purple/Deep Purple - Burn - 06 - Whats Goin On Here.mp3.wav
# deep_purple/Deep Purple - Burn - 07 - Mistreated.mp3.wav
# deep_purple/Deep Purple - Burn - 08 - A 200.mp3.wav
# deep_purple/Deep Purple - Deep Purple - 01 - Chasing Shadows.mp3.wav
# deep_purple/Deep Purple - Deep Purple - 02 - Blind.mp3.wav
# deep_purple/Deep Purple - Deep Purple - 03 - Lalena.mp3.wav
# deep_purple/Deep Purple - Deep Purple - 04 - a)Fault line b)The painter.mp3.wav
# deep_purple/Deep Purple - Deep Purple - 06 - The Bird Has Flown.mp3.wav
# deep_purple/Deep Purple - Deep Purple - 07 - April.mp3.wav
# deep_purple/Deep Purple - Deep Purple In Rock - 01- Speed King.mp3.wav
# deep_purple/Deep Purple - Deep Purple In Rock - 02 - Bloodsucker.mp3.wav
# deep_purple/Deep Purple - Deep Purple In Rock - 03 - Child In Time.mp3.wav
# deep_purple/Deep Purple - Deep Purple In Rock - 04 - Flight Of The Rat.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD1-04 - Pictures Of Home.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD1-05 - Black Night.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD1-06 - Cascades - I`m Not Your Lover.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD1-07 - Sometimes I Feel Like Screaming.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD1-08 - Woman From Tokyo.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD1-09 - No one came.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD1-10 - The Purpendicular Waltz.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD2-01- Rosas Cantina.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD2-02 - Smoke On The Water.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD2-03 - When A Blind Man Cries.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD2-04 - Speed King.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD2-05 - Perfect Strangers.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD2-06 - Hey Cisco.mp3.wav
# deep_purple/Deep Purple - Live At The Olympia 96 - CD2-07 - Highway Star.mp3.wav
# deep_purple/Deep Purple - PerfectStrangers - 01 - Knocking At Your Backdoor.mp3.wav
# deep_purple/Deep Purple - PerfectStrangers - 02 - Under The Gun.mp3.wav
# deep_purple/Deep Purple - PerfectStrangers - 04 - Mean Streak.mp3.wav
# deep_purple/Deep Purple - PerfectStrangers - 05 - Perfect Strangers.mp3.wav
# deep_purple/Deep Purple - PerfectStrangers - 07 - Wasted Sunsets.mp3.wav
# deep_purple/Deep Purple - PerfectStrangers - 08 - Hungry Daze.mp3.wav
# deep_purple/Deep Purple - PerfectStrangers - 09 - Not Responsible.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 01 - VavoomTed The Mechanic.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 02 - Loosen My Strings.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 03 - Soon Forgotten.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 04 - Sometimes I Feel Like Screaming.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 05 - Cascades Im Not Your Lover.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 06 - The Aviator.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 07 -  Rosas Cantina.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 08 - A Castle Full Of Rascals.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 09 - A Touch Away.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 10 - Hey Cisco.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 11 - Somebody Stole My Guitar.mp3.wav
# deep_purple/Deep Purple - Purpendicular - 12 - The Purpendicular Waltz.mp3.wav
# deep_purple/Deep Purple - Shades Of Deep Purple - 01 - And The Adress.mp3.wav
# deep_purple/Deep Purple - Shades Of Deep Purple - 02 - Hush.mp3.wav
# deep_purple/Deep Purple - Shades Of Deep Purple - 03 - One More Rainy Day.mp3.wav
# deep_purple/Deep Purple - Shades Of Deep Purple - 04 - Prelude Happiness.mp3.wav
# deep_purple/Deep Purple - Shades Of Deep Purple - 05 - Mandrake Root.mp3.wav
# deep_purple/Deep Purple - Shades Of Deep Purple - 06 - Help.mp3.wav
# deep_purple/Deep Purple - Shades Of Deep Purple - 07 - Love Help Me.mp3.wav
# deep_purple/Deep Purple - Shades Of Deep Purple - 08 - Hey Joe.mp3.wav
# deep_purple/Deep Purple - Slaves And Masters - 01 - King Of Drams.mp3.wav
# deep_purple/Deep Purple - Slaves And Masters - 02 - The Cut Runs Deep.mp3.wav
# deep_purple/Deep Purple - Slaves And Masters - 03 - Fire In The Basement.mp3.wav
# deep_purple/Deep Purple - Slaves And Masters - 04 - Fortuneteller.mp3.wav
# deep_purple/Deep Purple - Slaves And Masters - 05 - Truth Hurts.mp3.wav
# deep_purple/Deep Purple - Slaves And Masters - 06 - Love Conquers All.mp3.wav
# deep_purple/Deep Purple - Slaves And Masters - 07 - Breakfast In Bed.mp3.wav
# deep_purple/Deep Purple - Slaves And Masters - 08 - Too Much Is Not Enough.mp3.wav
# deep_purple/Deep Purple - Slaves And Masters - 09 - Wicked Ways.mp3.wav
# deep_purple/Deep Purple - Stormbringer - 01 - Stormbringer.mp3.wav
# deep_purple/Deep Purple - Stormbringer - 03 - Holy Man.mp3.wav
# deep_purple/Deep Purple - Stormbringer - 04 - Hold On.mp3.wav
# deep_purple/Deep Purple - Stormbringer - 05 - Lady Double Dealer.mp3.wav
# deep_purple/Deep Purple - Stormbringer - 06 - You Cant Do It Right.mp3.wav
# deep_purple/Deep Purple - Stormbringer - 07 - High Ball Shooter.mp3.wav
# deep_purple/Deep Purple - Stormbringer - 08 - The Gypsy.mp3.wav
# deep_purple/Deep Purple - Stormbringer - 09 - Soldier Of Fortune.mp3.wav
# deep_purple/Deep Purple - The Battle Rages On - 01 - The Battle Rages on.mp3.wav
# deep_purple/Deep Purple - The Battle Rages On - 02 - Lick It Up.mp3.wav
# deep_purple/Deep Purple - The Battle Rages On - 03 - Anya.mp3.wav
# deep_purple/Deep Purple - The Battle Rages On - 04 - Talk About Love.mp3.wav
# deep_purple/Deep Purple - The Battle Rages On - 05 - Time To Kill.mp3.wav
# deep_purple/Deep Purple - The Battle Rages On - 06 - Ramshackle Man.mp3.wav
# deep_purple/Deep Purple - The Battle Rages On - 07 - A Twist In The Tale.mp3.wav
# deep_purple/Deep Purple - The Battle Rages On - 08 - Nasty Piece Of Work.mp3.wav
# deep_purple/Deep Purple - The Battle Rages On - 09 - Solitaire.mp3.wav
# deep_purple/Deep Purple - The Battle Rages On - 10 - One Mans Meat.mp3.wav
# deep_purple/Deep Purple - The Book Of Taliesyn - 02 - Wring That Neck.mp3.wav
# deep_purple/Deep Purple - The Book Of Taliesyn - 03 - Kentucky Woman.mp3.wav
# deep_purple/Deep Purple - The Book Of Taliesyn - 04 - a)Exposition b)We Can Work It Out.mp3.wav
# deep_purple/Deep Purple - The Book Of Taliesyn - 05 - Shield.mp3.wav
# deep_purple/Deep Purple - Who Do We Think We Are - 01 - Woman From Tokio.mp3.wav
#
# Out of 157 Deep Purple samples, 107 are outliers

# %%
import pandas as pd

from collections import Counter
from sklearn import svm

jc_df = pd.read_csv('./johnny_cash_data.csv')

# Drop columns 'Class' and 'Path'
jc_df_cleaned = jc_df.drop(['Path', 'Class'], axis=1)

jc_df_train_samples = jc_df_cleaned.values.tolist()

estimator = svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.1)
estimator.fit(jc_df_train_samples)
jc_pred = estimator.predict(jc_df_train_samples)

print("Deep Purple Outlier Analysis:")
jc_outlier_count = Counter(jc_pred)
print("Outlier Count: ", jc_outlier_count[-1])
print("Inlier Count: ", jc_outlier_count[1])

# Add outliers data as last column to data sample
jc_df["Outliers"] = jc_pred

for sample in jc_df.values.tolist():
    if (sample[-1] == -1):
        print(sample[0])

jc_outlier_count = len(jc_df.loc[jc_df["Outliers"] == -1])

print("\nOut of {} Johnny Cash samples, {} are outliers".format(jc_pred.shape[0], jc_outlier_count))
# Out:
# Deep Purple Outlier Analysis:
# Outlier Count:  77
# Inlier Count:  30
# Johnny_cash/02 - I Will Rock And Roll With You.mp3.wav
# Johnny_cash/02 - One Piece At A Time.mp3.wav
# Johnny_cash/02 - Paul Revere.mp3.wav
# Johnny_cash/02 - The Devil To Pay.mp3.wav
# Johnny_cash/02 - The Road to Kaintuck.mp3.wav
# Johnny_cash/02 - Without Love.mp3.wav
# Johnny_cash/03 - Ballad of Little Fauss and Big Halsy (Instrumental).mp3.wav
# Johnny_cash/03 - Call Daddy From The Mines.mp3.wav
# Johnny_cash/03 - Cause I Love You.mp3.wav
# Johnny_cash/03 - Hungry.mp3.wav
# Johnny_cash/03 - In A Young Girls Mind.mp3.wav
# Johnny_cash/03 - The Diplomat.mp3.wav
# Johnny_cash/03 - W-o-m-a-n.mp3.wav
# Johnny_cash/04 - Cowboy Who Started The Fight.mp3.wav
# Johnny_cash/04 - Mountain Lady.mp3.wav
# Johnny_cash/04 - Narration.mp3.wav
# Johnny_cash/04 - No Expectations.mp3.wav
# Johnny_cash/04 - See Ruby Fall.mp3.wav
# Johnny_cash/04 - The Frozen Four Hundred Pound Fair To Middlin Cotton Picker.mp3.wav
# Johnny_cash/04 - The Road to Kaintuck.mp3.wav
# Johnny_cash/04 - This Town.mp3.wav
# Johnny_cash/05 - Cisco Cliftons Fillin Station.mp3.wav
# Johnny_cash/05 - It Comes And Goes.mp3.wav
# Johnny_cash/05 - Little Man.mp3.wav
# Johnny_cash/06 - Flesh and Blood (Instrumental).mp3.wav
# Johnny_cash/06 - I Ride An Old Paint.mp3.wav
# Johnny_cash/06 - Itll Be Her.mp3.wav
# Johnny_cash/06 - Little Man (Instrumental).mp3.wav
# Johnny_cash/06 - Rockabilly Blues (Texas 1955).mp3.wav
# Johnny_cash/06 - Sing A Traveling Song.mp3.wav
# Johnny_cash/06 - Sold Out of Flagpoles.mp3.wav
# Johnny_cash/06 - The Battle of New Orleans.mp3.wav
# Johnny_cash/06 - The Masterpiece.mp3.wav
# Johnny_cash/07 - Cause I Love You.mp3.wav
# Johnny_cash/07 - Committed To Parkview.mp3.wav
# Johnny_cash/07 - If I Were A Carpenter.mp3.wav
# Johnny_cash/07 - Narration.mp3.wav
# Johnny_cash/07 - Southwestward.mp3.wav
# Johnny_cash/07 - The Gambler.mp3.wav
# Johnny_cash/07 - The Last Time.mp3.wav
# Johnny_cash/07 - Wanted Man.mp3.wav
# Johnny_cash/07 - You And Tennessee.mp3.wav
# Johnny_cash/08 - Another Song To Sing.mp3.wav
# Johnny_cash/08 - Cajun Born.mp3.wav
# Johnny_cash/08 - Hardin Wouldnt Run.mp3.wav
# Johnny_cash/08 - Remember the Alamo.mp3.wav
# Johnny_cash/08 - Rollin Free (Instrumental).mp3.wav
# Johnny_cash/08 - Shes A Go-er.mp3.wav
# Johnny_cash/09 - Blistered.mp3.wav
# Johnny_cash/09 - It Aint Nothing New Babe.mp3.wav
# Johnny_cash/09 - Narration.mp3.wav
# Johnny_cash/09 - Opening the West.mp3.wav
# Johnny_cash/09 - The Flint Arrowhead.mp3.wav
# Johnny_cash/09 - True Love is Greater than Friendship.mp3.wav
# Johnny_cash/10 - Go On Blues.mp3.wav
# Johnny_cash/10 - Lorena.mp3.wav
# Johnny_cash/10 - Mister Garfield.mp3.wav
# Johnny_cash/10 - Movin.mp3.wav
# Johnny_cash/10 - One Way Rider.mp3.wav
# Johnny_cash/10 - Shrimpin Sailin.mp3.wav
# Johnny_cash/11 - Ive Got A Thing About Trains.mp3.wav
# Johnny_cash/11 - Little Man (Instrumental2).mp3.wav
# Johnny_cash/11 - Standing On The Promises.mp3.wav
# Johnny_cash/11 - The Gettysburg Adress.mp3.wav
# Johnny_cash/11 - The Streets of Laredo.mp3.wav
# Johnny_cash/11 - The Walls of A Prison.mp3.wav
# Johnny_cash/12 - Amazing Grace.mp3.wav
# Johnny_cash/12 - Jesus Was A Carpenter.mp3.wav
# Johnny_cash/12 - The West.mp3.wav
# Johnny_cash/12 - True Love is Greater than Friendship (Instrumental).mp3.wav
# Johnny_cash/13 - Big Foot.mp3.wav
# Johnny_cash/13 - Johnny Reb.mp3.wav
# Johnny_cash/13 - Movin (Instrumental).mp3.wav
# Johnny_cash/14 - A Letter From Home.mp3.wav
# Johnny_cash/14 - Like A Young Colt.mp3.wav
# Johnny_cash/15 - Bury Me Not On The Lone Prairie.mp3.wav
# Johnny_cash/18 - On Wheels and Wings.mp3.wav
#
# Out of 107 Johnny Cash samples, 77 are outliers

# %% [markdown]
# ## Part 3
# Eminem & Black Sabath

# %%
from pandas import DataFrame
import pandas as pd

e_bs_df = pd.read_csv('./e_bs.csv')
bs_e_df = pd.read_csv('./bs_e.csv')

# Shuffle rows as for each csv file, novelty rows are appended to the end of dataset
# e_bs_ds = e_bs_df.sample(frac=1)
e_bs_ds = e_bs_df
# bs_e_ds = bs_e_df.sample(frac=1)
bs_e_ds = bs_e_df

# Drop columns 'Class' and 'Path'
e_bs_ds_cleaned = e_bs_ds.drop(['Path', 'Class'], axis=1)
bs_e_ds_cleaned = bs_e_ds.drop(['Path', 'Class'], axis=1)

e_bs_train_samples = e_bs_ds_cleaned.values.tolist()
bs_e_train_samples = bs_e_ds_cleaned.values.tolist()

# %%
from collections import Counter
from sklearn import svm

estimator = svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.1)

# Eminem with Black Sabbath novelty samples
estimator.fit(e_bs_train_samples)
e_bs_pred = estimator.predict(e_bs_train_samples)

print("Eminem - Black Sabath Outlier Analysis:")
e_bs_outlier_count = Counter(e_bs_pred)
print("Outlier Count: ", e_bs_outlier_count[-1])
print("Inlier Count: ", e_bs_outlier_count[1])

# Add outliers data as last column to data sample
e_bs_ds["Outliers"] = e_bs_pred

# Get only Black Sabath rows (should be 10 rows)
bs_samples = e_bs_ds.loc[e_bs_ds["Class"] == 'black_sabath']

for sample in bs_samples.values.tolist():
    print("{} ---> {}".format(sample[0], "Outlier (-1)" if sample[-1] == -1 else "Inlier (1)"))

bs_outliers_count = len(bs_samples.loc[bs_samples["Outliers"] == -1])

print("\nOut of 10 Black Sabath samples, {} are outliers".format(bs_outliers_count))
print("Detection rate: {}%".format((bs_outliers_count/10)*100))
# Out:
# Eminem - Black Sabath Outlier Analysis:
# Outlier Count:  73
# Inlier Count:  37
# black_sabath/02 - After Forever.flac.mp3.wav ---> Outlier (-1)
# black_sabath/02 - Behind The Wall Of Sleep.flac.mp3.wav ---> Outlier (-1)
# black_sabath/02 - Dont Start (Too Late).flac.mp3.wav ---> Outlier (-1)
# black_sabath/02 - Fairies Wear Boots.flac.mp3.wav ---> Outlier (-1)
# black_sabath/02 - Hole In The Sky.flac.mp3.wav ---> Outlier (-1)
# black_sabath/02 - Johnny Blade.flac.mp3.wav ---> Outlier (-1)
# black_sabath/02 - Orchid-Lord Of This World.flac.mp3.wav ---> Outlier (-1)
# black_sabath/02 - Paranoid.flac.mp3.wav ---> Outlier (-1)
# black_sabath/02 - Sweet Leaf.flac.mp3.wav ---> Outlier (-1)
# black_sabath/02 - The Wizard.flac.mp3.wav ---> Outlier (-1)
#
# Out of 10 Black Sabath samples, 10 are outliers
# Detection rate: 100.0%

# %%
# Black Sabath with Eminem novelty samples
estimator.fit(bs_e_train_samples)
bs_e_pred = estimator.predict(bs_e_train_samples)

# Add outliers data as last column to data sample
bs_e_ds["Outliers"] = bs_e_pred

print("\nBlack Sabath - Eminem Outlier Analysis:")
bs_e_outlier_count = Counter(bs_e_pred)
print("Outlier Count: ", bs_e_outlier_count[-1])
print("Inlier Count: ", bs_e_outlier_count[1])

# Get only Deep Purple rows (should be 10 rows)
e_samples = bs_e_ds.loc[bs_e_ds["Class"] == 'Eminem']

for sample in e_samples.values.tolist():
    print("{} ---> {}".format(sample[0], "Outlier (-1)" if sample[-1] == -1 else "Inlier (1)"))

e_outliers_count = len(e_samples.loc[e_samples["Outliers"] == -1])

print("\nOut of 10 Deep Purple samples, {} are outliers".format(e_outliers_count))
print("Detection rate: {}%".format((e_outliers_count/10)*100))
# Out:
# Black Sabath - Eminem Outlier Analysis:
# Outlier Count:  66
# Inlier Count:  44
# Eminem/9-07 I Am (Woogie Blend).mp3.wav ---> Outlier (-1)
# Eminem/9-08 Bullys Pt.2.mp3.wav ---> Outlier (-1)
# Eminem/9-09 Encore.mp3.wav ---> Outlier (-1)
# Eminem/9-10 Mic Check (Crazy).mp3.wav ---> Outlier (-1)
# Eminem/9-11 Freestyle.mp3.wav ---> Outlier (-1)
# Eminem/9-12 Soilder (Remix).mp3.wav ---> Outlier (-1)
# Eminem/9-13 Hellbound.mp3.wav ---> Outlier (-1)
# Eminem/9-14 Oh Shit.mp3.wav ---> Outlier (-1)
# Eminem/9-15 Pills.mp3.wav ---> Inlier (1)
# Eminem/9-16 Came 2 Party.mp3.wav ---> Inlier (1)
#
# Out of 10 Deep Purple samples, 8 are outliers
# Detection rate: 80.0%
